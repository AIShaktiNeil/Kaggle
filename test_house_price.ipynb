# %%
import pandas as pd

# %%
df_test = pd.read_csv(r"C:\Users\DELL\Desktop\test.csv")
df_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
# Keep the 'Id' column
ids = df_test['Id']

# Drop the 'Id' column from the test data
# df_test = df_test.drop('Id', axis=1)

# %%
# Identify numeric columns with missing values and their count
numeric_columns_with_na = df_test.select_dtypes(include=['number']).isnull().sum()
numeric_columns_with_missing_values = numeric_columns_with_na[numeric_columns_with_na > 0]

# Display the numeric columns with missing values and their count
print(numeric_columns_with_missing_values)
# Out:
# LotFrontage     227
# MasVnrArea       15
# BsmtFinSF1        1
# BsmtFinSF2        1
# BsmtUnfSF         1
# TotalBsmtSF       1
# BsmtFullBath      2
# BsmtHalfBath      2
# GarageYrBlt      78
# GarageCars        1
# GarageArea        1
# dtype: int64

# %%
df_test['LotFrontage'].fillna(df_test['LotFrontage'].mean(),inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5456\535834273.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test['LotFrontage'].fillna(df_test['LotFrontage'].mean(),inplace=True)

# %%
df_test.dropna(subset=["MasVnrArea",
"BsmtFinSF1",  
"BsmtFinSF2",  
"BsmtUnfSF",   
"TotalBsmtSF",
"BsmtFullBath",
"BsmtHalfBath",
"GarageYrBlt", 
"GarageCars",  
"GarageArea",], inplace=True)

# %%
ids = df_test['Id']
df_test = df_test.drop('Id', axis=1)

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler
enc= LabelEncoder()
scaler= StandardScaler()
# Apply label encoding to categorical columns
for column in df_test.select_dtypes(include=['object']).columns:
    df_test[column] = enc.fit_transform(df_test[column])

# %%
# Scale the test data
df_test_scaled = scaler.fit_transform(df_test)

# %%
df_test

# %%
import joblib

# Load the model from the file
loaded_model = joblib.load(r'C:\Users\DELL\Downloads\best_model_house_price.pkl')

# %%
# Make predictions on the test data
y_pred = loaded_model.predict(df_test_scaled)

# %%
y_pred
# Out:
# array([26806.053, 27516.38 , 26468.746, ..., 46262.22 , 28608.574,
#        27662.469], dtype=float32)

# %%
# Add the predicted 'SalePrice' to the test DataFrame
df_test['SalePrice'] = y_pred
# Print the DataFrame with predictions
df_test
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0             20         2         80.0    11622       1      2         3
# 1             20         3         81.0    14267       1      2         0
# 2             60         3         74.0    13830       1      2         0
# 3             60         3         78.0     9978       1      2         0
# 4            120         3         43.0     5005       1      2         0
# ...          ...       ...          ...      ...     ...    ...       ...
# 1451          20         3         80.0    13384       1      2         3
# 1452         160         4         21.0     1533       1      2         3
# 1455         160         4         21.0     1894       1      2         3
# 1456          20         3        160.0    20000       1      2         3
# 1458          60         3         74.0     9627       1      2         3
#
#       LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
ids
# Out:
# 0       1461
# 1       1462
# 2       1463
# 3       1464
# 4       1465
#         ...
# 1451    2912
# 1452    2913
# 1455    2916
# 1456    2917
# 1458    2919
# Name: Id, Length: 1365, dtype: int64

# %%
df_test.drop(columns="Id",axis=1,inplace=True)

# %%
df_test.insert(0, 'Id', ids)

# %%
df_test
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     1461          20         2         80.0    11622       1      2
# 1     1462          20         3         81.0    14267       1      2
# 2     1463          60         3         74.0    13830       1      2
# 3     1464          60         3         78.0     9978       1      2
# 4     1465         120         3         43.0     5005       1      2
# ...    ...         ...       ...          ...      ...     ...    ...
# 1451  2912          20         3         80.0    13384       1      2
# 1452  2913         160         4         21.0     1533       1      2
# 1455  2916         160         4         21.0     1894       1      2
# 1456  2917          20         3        160.0    20000       1      2
# 1458  2919          60         3         74.0     9627       1      2
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
df_test1 = df_test[['Id','SalePrice']]

# %%
df_test1
# Out:
#         Id     SalePrice
# 0     1461  26806.052734
# 1     1462  27516.380859
# 2     1463  26468.746094
# 3     1464  26468.746094
# 4     1465  28020.337891
# ...    ...           ...
# 1451  2912  29802.291016
# 1452  2913  46262.218750
# 1455  2916  46262.218750
# 1456  2917  28608.574219
# 1458  2919  27662.468750
#
# [1365 rows x 2 columns]
