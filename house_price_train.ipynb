# %%
import pandas as pd
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\DELL\Downloads\house_price_train.csv")
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# df_test = pd.read_csv(r"‪C:\Users\DELL\Desktop\test.csv")
df_test = pd.read_csv(r"C:\Users\DELL\Desktop\test.csv")
df_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
pd.set_option('display.max_columns', None)
print(df.isnull().sum())
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df['YearRemodAdd']
# Out:
# 0       2003
# 1       1976
# 2       2002
# 3       1970
# 4       2000
#         ...
# 1455    2000
# 1456    1988
# 1457    2006
# 1458    1996
# 1459    1965
# Name: YearRemodAdd, Length: 1460, dtype: int64

# %%
# Select columns with integer data type
int_columns = df.select_dtypes(include='int64')

# Filter columns with null values
int_columns_with_nulls = int_columns.columns[int_columns.isnull().any()]

# Display columns with null values
df[int_columns_with_nulls].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
# Filter columns with null values
columns_with_nulls = df.columns[df.isnull().any()]

# Display columns with null values
df[columns_with_nulls].isnull().sum()
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(25,20))
sns.heatmap(int_columns.corr(),annot = True , cmap = "coolwarm")
plt.show()

# %%
for column in df.select_dtypes(include='object').columns:
    print(df[column].value_counts())
# Out:
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: count, dtype: int64
# Street
# Pave    1454
# Grvl       6
# Name: count, dtype: int64
# Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64
# LotShape
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: count, dtype: int64
# LandContour
# Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# Name: count, dtype: int64
# Utilities
# AllPub    1459
# NoSeWa       1
# Name: count, dtype: int64
# LotConfig
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: count, dtype: int64
# LandSlope
# Gtl    1382
# Mod      65
# Sev      13
# Name: count, dtype: int64
# Neighborhood
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Example: Distribution of a numerical column
sns.histplot(df['SalePrice'], kde=True)
plt.show()

# Example: Count plot of a categorical column
sns.countplot(x='MSZoning', data=df)
plt.show()

# %%
int_columns.shape
# Out:
# (1460, 35)

# %%
df_dropped = df.drop(columns='Id',axis=1)

# %%
plt.figure(figsize=(20,15))
for col in int_columns.columns:
    plt.figure()
    sns.boxplot(data=int_columns[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
df['LowQualFinSF'].value_counts()
# Out:
# LowQualFinSF
# 0      1434
# 80        3
# 360       2
# 205       1
# 479       1
# 397       1
# 514       1
# 120       1
# 481       1
# 232       1
# 53        1
# 515       1
# 156       1
# 473       1
# 420       1
# 390       1
# 371       1
# 392       1
# 144       1
# 572       1
# 528       1
# 234       1
# 513       1
# 384       1
# Name: count, dtype: int64

# %%
import numpy as np
colums_with_outlier = []
for col in df.select_dtypes(include=['int64']).columns:
    uq,lq=np.percentile(df[col],(75,25))
    iqr = uq-lq
    lower_boundry = uq+1.5*iqr
    upper_boundry = lq-1.5*iqr
    if((df[col]< lower_boundry) | (df[col]> upper_boundry)).any():
      colums_with_outlier.append(col)
print(colums_with_outlier)
# Out:
# ['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']

# %%
len(colums_with_outlier)
# Out:
# 35

# %%
# Count the number of outliers in each column using IQR method
outlier_counts = {}
for col in df_null_removed.select_dtypes(include=['int64']).columns:
    uq,lq=np.percentile(df_null_removed[col],(75,25))
    iqr = uq-lq
    lower_boundry = uq+1.5*iqr
    upper_boundry = lq-1.5*iqr
    outliers = ((df_null_removed[col] < lower_boundry) | (df_null_removed[col] > upper_boundry)).sum()
    outlier_counts[col] = outliers

# Display the count of outliers for each column
outlier_counts
# Out:
# {'Id': 1460,
#  'MSSubClass': 1460,
#  'LotArea': 1460,
#  'OverallQual': 1460,
#  'OverallCond': 1460,
#  'YearBuilt': 1460,
#  'YearRemodAdd': 1460,
#  'BsmtFinSF1': 1460,
#  'BsmtFinSF2': 167,
#  'BsmtUnfSF': 1460,
#  'TotalBsmtSF': 1460,
#  '1stFlrSF': 1460,
#  '2ndFlrSF': 1460,
#  'LowQualFinSF': 26,
#  'GrLivArea': 1460,
#  'BsmtFullBath': 1460,
#  'BsmtHalfBath': 82,
#  'FullBath': 1460,
#  'HalfBath': 1460,
#  'BedroomAbvGr': 1460,
#  'KitchenAbvGr': 68,
#  'TotRmsAbvGrd': 1460,
#  'Fireplaces': 1460,
#  'GarageCars': 1460,
#  'GarageArea': 1460,
#  'WoodDeckSF': 1460,
#  'OpenPorchSF': 1460,
#  'EnclosedPorch': 208,
#  '3SsnPorch': 24,
#  'ScreenPorch': 116,
#  'PoolArea': 7,
#  'MiscVal': 52,
#  'MoSold': 1460,
#  'YrSold': 1460,
#  'SalePrice': 1460}

# %%
from scipy import stats
import numpy as np

# Calculate Z-scores for numerical columns
z_scores = np.abs(stats.zscore(df_dropped.select_dtypes(include=['int64'])))

# Identify columns with outliers
columns_with_outliers = df_dropped.select_dtypes(include=['int64']).columns[(z_scores > 3).any(axis=0)]
print(len(columns_with_outliers))
# Out:
# 29

# %%
columns_with_outliers
# Out:
# Index(['MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'SalePrice'],
#       dtype='object')

# %%
int_columns.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# SalePrice        0
# dtype: int64

# %%
(df_enc.isnull().sum())
# Out:
# LotFrontage    259
# MasVnrArea       8
# GarageYrBlt     81
# dtype: int64

# %%
df_enc['LotFrontage'].fillna(df_enc['LotFrontage'].mean(),inplace=True)

# %%
# Drop rows with missing values in 'MasVnrArea' and 'GarageYrBlt' columns
df_enc.dropna(subset=['MasVnrArea', 'GarageYrBlt'], inplace=True)

# %%
df_enc
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0             60         3         65.0     8450       1      2         3
# 1             20         3         80.0     9600       1      2         3
# 2             60         3         68.0    11250       1      2         0
# 3             70         3         60.0     9550       1      2         0
# 4             60         3         84.0    14260       1      2         0
# ...          ...       ...          ...      ...     ...    ...       ...
# 1455          60         3         62.0     7917       1      2         3
# 1456          20         3         85.0    13175       1      2         3
# 1457          70         3         66.0     9042       1      2         3
# 1458          20         3         68.0     9717       1      2         3
# 1459          20         3         75.0     9937       1      2         3
#
#       LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# ...

# %%
# Identify columns with missing values and their count
missing_values = df_enc.isnull().sum()
columns_with_missing_values = missing_values[missing_values > 0]

# Display the columns with missing values and their count
print(columns_with_missing_values)
# Out:
# Series([], dtype: int64)

# %%
from sklearn.model_selection import train_test_split

x = df_enc.drop('SalePrice', axis=1)
y = df_enc['SalePrice']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)
# x_train_scaled = scaler.fit_transform(x_train)
# x_test_scaled = scaler.transform(x_test)

# %%
x.hist(figsize=(10,5));

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV ,cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
lis = [
     LinearRegression,
     LogisticRegression,
     DecisionTreeRegressor,
     RandomForestRegressor,
     GradientBoostingRegressor,
     SVR,
     XGBRegressor]

# %%
for i in lis:
    print(i)
    model = i()
    k = KFold(n_splits=5)
    print(cross_val_score(model,x_scaled,y,cv=k).mean())
# Out:
# <class 'sklearn.linear_model._base.LinearRegression'>
# -1.4583630241115543e+23
# <class 'sklearn.linear_model._logistic.LogisticRegression'>
# 0.010213669542136697
# <class 'sklearn.tree._classes.DecisionTreeRegressor'>
# 0.7223574199488821
# <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# 0.8479393969554956
# <class 'sklearn.ensemble._gb.GradientBoostingRegressor'>
# 0.882436320117668
# <class 'sklearn.svm._classes.SVR'>
# -0.05545488633937716
# <class 'xgboost.sklearn.XGBRegressor'>
# 0.8669381260871887

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = GradientBoostingRegressor()
model.fit(x_train,y_train)
model.score(x_train,y_train)
# Out:
# 0.9719814215737473

# %%
model.score(x_test,y_test)
# Out:
# 0.8967518276817611

# %%
model
# Out:
# GradientBoostingRegressor()

# %%
# Define the parameter grid for RandomizedSearchCV
param_grid =  {
        'n_estimators': [100, 200, 300],
        'learning_rate': [0.01, 0.1, 0.2],
        'max_depth': [3, 5, 7]
}

random= RandomizedSearchCV(model,param_distributions=param_grid,n_iter=20,cv=k,verbose=2)

# random_search = RandomizedSearchCV(estimator=best_model, param_distributions=param_grid[best_model_name], n_iter=50, cv=5, n_jobs=-1, verbose=2, random_state=42)
random.fit(x_train, y_train)

# Get the best model and parameters
best_model = random.best_estimator_
best_params = random.best_params_

print(f'Best Parameters: {best_params}')
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=300; total time=   3.2s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=300; total time=   3.4s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=300; total time=   3.2s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=300; total time=   3.1s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=300; total time=   3.1s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=200; total time=   1.3s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=200; total time=   1.3s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=200; total time=   1.2s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=200; total time=   1.3s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=200; total time=   1.2s
# [CV] END ...learning_rate=0.2, max_depth=3, n_estimators=300; total time=   1.8s
# ...

# %%
best_model.score(x_train,y_train)
# Out:
# 0.990473736086434

# %%
best_model.score(x_test,y_test)
# Out:
# 0.9055998130437833

# %%
# fimp=best_model.feature_importances_
feature_importances = pd.Series(best_model.feature_importances_, index=x.columns)

# Get the top 5 important features and plot them
top_features = feature_importances.nlargest(5)
top_features.plot(kind='barh')
plt.title('Top 5 Feature Importances')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %%
import joblib

# Save the best model to a file
joblib.dump(best_model, 'best_model_house_price.pkl')
# Out:
# ['best_model_house_price.pkl']

# %%
x_train.shape
# Out:
# (1096, 79)
